# %%
import requests
import pandas as pd

# %%
headers = {
    'authority': 'www.autolist.com',
    'sec-ch-ua': '" Not A;Brand";v="99", "Chromium";v="96", "Google Chrome";v="96"',
    'accept': '*/*',
    'x-requested-with': 'XMLHttpRequest',
    'sec-ch-ua-mobile': '?0',
    'x-autolist-session-guid': '1ab4a72a-18e4-4cbd-ac95-9bb9ace3345a',
    'user-agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36',
    'sec-ch-ua-platform': '"Linux"',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://www.autolist.com/listings',
    'accept-language': 'fr-FR,fr;q=0.9,en-US;q=0.8,en;q=0.7',
    'cookie': 'ec=eyJlZGdlVXNlckFnZW50IjoiTW96aWxsYS81LjAgKFgxMTsgTGludXggeDg2XzY0KSBBcHBsZVdlYktpdC81MzcuMzYgKEtIVE1MLCBsaWtlIEdlY2tvKSBDaHJvbWUvOTYuMC40NjY0LjQ1IFNhZmFyaS81MzcuMzYifQ==; client_guid_timestamp=51f37bb0-3c6b-4013-86fb-7f98eb92d6ae.1641825025083; scavenger-a493=...; _sp_ses.8ca5=*; _gid=GA1.2.1134897533.1641825047; _ga_152345333=GS1.1.1641825030.1.1.1641825129.0; AMP_TOKEN=%24NOT_FOUND; _ga=GA1.2.1653055854.1641825033; sp-nuid=ab7d8e20-85ef-4ac2-899f-9cece14d63af; _gcl_au=1.1.1737095282.1641825144; cto_bundle=38X3p182ZXJGdmclMkI3M0pMRm5rOFRoTU5hUEx0VU8ySmxSJTJGdGhjJTJGWG9TUDRycnhUOFE4TkglMkJKQjh4WktSbFNnWjQ2cURoVHIwTDdqS3BoQWpqRWNGbGVmeSUyRmlEd21vblFHWG1MOWM5VWZ1MXNlak9FQnZnWGt4SldnMVQ0RUM1SDVaQVJubU1BdXBZYnVGTHdrVUswbEhHRnVnJTNEJTNE; _sp_id.8ca5=a86b051f-ff2a-4649-b109-3eb34949a5d8.1641825034.1.1641825292.1641825034.02d430f9-b171-46cc-bd87-013104bf6ded',
    'if-none-match': 'W/"e6a487b1512d4740eaacb37534052c2b"',
}

params = (
    ('make', 'Tesla'),
    ('location', 'San Francisco, CA'),
    ('latitude', '37.7749295'),
    ('longitude', '-122.4194155'),
    ('radius', '50'),
    ('page', '1'),
)

response = requests.get('https://www.autolist.com/api/cwv/seo/listings', headers=headers, params=params)

# %% [raw]
# response

# %%
results_json = response.json()

# %%
results_json
# Out:
# {'total_results_count': 1187,
#  'make_model_name': 'Tesla',
#  'trims': [],
#  'ad_info': {'ad_unit': '/19485787/AutoList.com/Search_Results_Page/Tesla',
#   'make': 'Tesla',
#   'model': None,
#   'page_type': 'srp',
#   'cpo': False,
#   'body_style': None,
#   'year': 2023,
#   'age_type': 'new',
#   'app': 'web',
#   'seller_id': None,
#   'content_url': 'https://www.autolist.com/listings#latitude=37.7749295&location=San+Francisco%2C+CA&longitude=-122.4194155&make=Tesla&page=1&radius=50'},
#  'search_results': [{'available_nationwide': False,
#    'created_at': 1637600594,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EB4JF094546',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EB4JF094546',
#    'clickoff_url': 'https://www.shift.com/car/c191146?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 232010619,
# ...

# %%
type(results_json)
# Out:
# dict

# %%
results_json.keys()
# Out:
# dict_keys(['total_results_count', 'make_model_name', 'trims', 'ad_info', 'search_results', 'html'])

# %%
results_json['search_results']
# Out:
# [{'available_nationwide': False,
#   'created_at': 1637600594,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EB4JF094546',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EB4JF094546',
#   'clickoff_url': 'https://www.shift.com/car/c191146?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 232010619,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/12/08/18/14/2018_tesla_model_3-pic-3933473144524356802-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--dPaVpWMF--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/12/08/18/14/2018_tesla_model_3-pic-3933473144524356802-1024x768.jpeg',
#   'lat': 37.6442,
#   'lon': -122.398,
#   'year': 2018,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$45,950',
# ...

# %%
len(results_json['search_results'])
# Out:
# 20

# %%
results_json['search_results'][0]
# Out:
# {'available_nationwide': False,
#  'created_at': 1637600594,
#  'recent_price_drop': False,
#  'is_hot': False,
#  'href_target': '/listings/5YJ3E1EB4JF094546',
#  'vdp_url': '/tesla-model+3#vin=5YJ3E1EB4JF094546',
#  'clickoff_url': 'https://www.shift.com/car/c191146?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#  'accepts_leads': True,
#  'open_in_new_window': False,
#  'id': 232010619,
#  'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/12/08/18/14/2018_tesla_model_3-pic-3933473144524356802-1024x768.jpeg',
#  'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--dPaVpWMF--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/12/08/18/14/2018_tesla_model_3-pic-3933473144524356802-1024x768.jpeg',
#  'lat': 37.6442,
#  'lon': -122.398,
#  'year': 2018,
#  'make': 'Tesla',
#  'model': 'Model 3',
#  'model_id': 2217,
#  'display_color': '',
#  'price': '$45,950',
#  'price_unformatted': 45950,
# ...

# %%
results_json['search_results'][0]['model']
# Out:
# 'Model 3'

# %%
results_json['search_results'][0]['mileage']
# Out:
# '35,219 Miles'

# %%
results_json['search_results'][0]['year']
# Out:
# 2018

# %%
results_json['search_results'][0]['dealer_name']
# Out:
# 'Shift SF - Test Drives Delivered To You'

# %%
results_json['search_results'][0]['price']
# Out:
# '$45,950'

# %%
result_items = results_json['search_results']

# %%
model = []
mileage = []
year = []
dealer_name = []
price = []
for results in result_items:
    model.append(results['model'])
    mileage.append(results['mileage'])
    year.append(results['year'])
    dealer_name.append(results['dealer_name'])
    price.append(results['price'])

# %%
model
# Out:
# ['Model 3',
#  'Model 3',
#  'Model 3',
#  'Model 3',
#  'Model 3',
#  'Model 3',
#  'Model S',
#  'Model 3',
#  'Model 3',
#  'Model 3',
#  'Model 3',
#  'Model 3',
#  'Model Y',
#  'Model S',
#  'Model 3',
#  'Model 3',
#  'Model S',
#  'Model Y',
#  'Model 3',
#  'Model 3']

# %%
tesla_df = pd.DataFrame({'Model':model, 'Mileage':mileage, 'Year':year, 'Dealer_name':dealer_name, 'Price':price})
tesla_df
# Out:
#       Model       Mileage  Year  \
# 0   Model 3  35,219 Miles  2018
# 1   Model 3  10,640 Miles  2020
# 2   Model 3  53,129 Miles  2018
# 3   Model 3  28,890 Miles  2019
# 4   Model 3   5,616 Miles  2020
# 5   Model 3  11,643 Miles  2020
# 6   Model S  59,585 Miles  2014
# 7   Model 3  31,518 Miles  2018
# 8   Model 3  17,885 Miles  2018
# 9   Model 3  25,139 Miles  2019
# 10  Model 3  35,118 Miles  2018
# 11  Model 3   1,033 Miles  2021
# 12  Model Y   8,849 Miles  2021
# 13  Model S  42,249 Miles  2018
# 14  Model 3   2,134 Miles  2021
# 15  Model 3  32,780 Miles  2020
# 16  Model S  39,281 Miles  2014
# 17  Model Y  14,993 Miles  2020
# 18  Model 3   9,766 Miles  2021
# 19  Model 3  15,837 Miles  2019
#
#                                           Dealer_name    Price
# 0             Shift SF - Test Drives Delivered To You  $45,950
# 1             Shift SF - Test Drives Delivered To You  $53,350
# 2             Shift SF - Test Drives Delivered To You  $44,500
# ...

# %%
tesla_df.to_json('temp.json', orient='records', lines=True)

tesla_df.to_json('tesla_car.xlsx', index=False)

# %%
headers = {
    'authority': 'www.autolist.com',
    'sec-ch-ua': '" Not A;Brand";v="99", "Chromium";v="96", "Google Chrome";v="96"',
    'accept': '*/*',
    'x-requested-with': 'XMLHttpRequest',
    'sec-ch-ua-mobile': '?0',
    'x-autolist-session-guid': '1ab4a72a-18e4-4cbd-ac95-9bb9ace3345a',
    'user-agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36',
    'sec-ch-ua-platform': '"Linux"',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://www.autolist.com/listings',
    'accept-language': 'fr-FR,fr;q=0.9,en-US;q=0.8,en;q=0.7',
    'cookie': 'ec=eyJlZGdlVXNlckFnZW50IjoiTW96aWxsYS81LjAgKFgxMTsgTGludXggeDg2XzY0KSBBcHBsZVdlYktpdC81MzcuMzYgKEtIVE1MLCBsaWtlIEdlY2tvKSBDaHJvbWUvOTYuMC40NjY0LjQ1IFNhZmFyaS81MzcuMzYifQ==; client_guid_timestamp=51f37bb0-3c6b-4013-86fb-7f98eb92d6ae.1641825025083; scavenger-a493=...; _sp_ses.8ca5=*; _gid=GA1.2.1134897533.1641825047; _ga_152345333=GS1.1.1641825030.1.1.1641825129.0; AMP_TOKEN=%24NOT_FOUND; _ga=GA1.2.1653055854.1641825033; sp-nuid=ab7d8e20-85ef-4ac2-899f-9cece14d63af; _gcl_au=1.1.1737095282.1641825144; cto_bundle=38X3p182ZXJGdmclMkI3M0pMRm5rOFRoTU5hUEx0VU8ySmxSJTJGdGhjJTJGWG9TUDRycnhUOFE4TkglMkJKQjh4WktSbFNnWjQ2cURoVHIwTDdqS3BoQWpqRWNGbGVmeSUyRmlEd21vblFHWG1MOWM5VWZ1MXNlak9FQnZnWGt4SldnMVQ0RUM1SDVaQVJubU1BdXBZYnVGTHdrVUswbEhHRnVnJTNEJTNE; _sp_id.8ca5=a86b051f-ff2a-4649-b109-3eb34949a5d8.1641825034.1.1641825292.1641825034.02d430f9-b171-46cc-bd87-013104bf6ded',
    'if-none-match': 'W/"e6a487b1512d4740eaacb37534052c2b"',
}

model = []
mileage = []
year = []
dealer_name = []
price = []

for i in range(1, 6):
    params = (
        ('make', 'Tesla'),
        ('location', 'San Francisco, CA'),
        ('latitude', '37.7749295'),
        ('longitude', '-122.4194155'),
        ('radius', '50'),
        ('page', str(i)),
    )

    response = requests.get('https://www.autolist.com/api/cwv/seo/listings', headers=headers, params=params)
    
    result_json = response.json()
    
    result_items = result_json['search_results']
    
    for results in result_items:
        model.append(results['model'])
        mileage.append(results['mileage'])
        year.append(results['year'])
        dealer_name.append(results['dealer_name'])
        price.append(results['price'])

# %%
tesla_all_df = pd.DataFrame({'Model':model, 'Mileage':mileage, 'Year':year, 'Dealer_name':dealer_name, 'Price':price})

# %%
tesla_all_df
# Out:
#       Model       Mileage  Year                              Dealer_name  \
# 0   Model 3  35,219 Miles  2018  Shift SF - Test Drives Delivered To You
# 1   Model 3  10,640 Miles  2020  Shift SF - Test Drives Delivered To You
# 2   Model 3  53,129 Miles  2018  Shift SF - Test Drives Delivered To You
# 3   Model 3  28,890 Miles  2019  Shift SF - Test Drives Delivered To You
# 4   Model 3   5,616 Miles  2020  Shift SF - Test Drives Delivered To You
# ..      ...           ...   ...                                      ...
# 95  Model 3  36,325 Miles  2019                    One Toyota Of Oakland
# 96  Model 3  54,647 Miles  2019                      San Jose Mitsubishi
# 97  Model X  48,877 Miles  2016                   North State Auto Sales
# 98  Model Y  49,869 Miles  2020                       Hayward Mitsubishi
# 99  Model 3   6,230 Miles  2020             CarMax Santa Rosa - Now Open
#
#       Price
# 0   $45,950
# 1   $53,350
# 2   $44,500
# 3   $50,450
# 4   $53,450
# ...

# %%
tesla_all_df.to_json(orient='records')
# Out:
# '[{"Model":"Model 3","Mileage":"35,219 Miles","Year":2018,"Dealer_name":"Shift SF - Test Drives Delivered To You","Price":"$45,950"},{"Model":"Model 3","Mileage":"10,640 Miles","Year":2020,"Dealer_name":"Shift SF - Test Drives Delivered To You","Price":"$53,350"},{"Model":"Model 3","Mileage":"53,129 Miles","Year":2018,"Dealer_name":"Shift SF - Test Drives Delivered To You","Price":"$44,500"},{"Model":"Model 3","Mileage":"28,890 Miles","Year":2019,"Dealer_name":"Shift SF - Test Drives Delivered To You","Price":"$50,450"},{"Model":"Model 3","Mileage":"5,616 Miles","Year":2020,"Dealer_name":"Shift SF - Test Drives Delivered To You","Price":"$53,450"},{"Model":"Model 3","Mileage":"11,643 Miles","Year":2020,"Dealer_name":"CarMax Fairfield - Now Offering Curbside Pickup And Home Delivery","Price":"$56,998"},{"Model":"Model S","Mileage":"59,585 Miles","Year":2014,"Dealer_name":"Shift SF - Test Drives Delivered To You","Price":"$37,950"},{"Model":"Model 3","Mileage":"31,518 Miles","Year":201
# ...
